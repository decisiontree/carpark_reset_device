# %% [markdown]
# ## Fix the query window issue and time comparison (one minor issue is that precision for string comparision is only up to second level)
# ## segment extraction works

# %%
#can we treat each device as slow change dimension (warehouse table) and store the "current" empty space magnetic field?
#It can be saved as a x, y, z timestamp , status relational table.
#when a car drive in, we 

import json

import pandas as pd
import boto3
import json
import decimal

from boto3.dynamodb.conditions import Key, Attr
from boto3 import resource

import time
from datetime import datetime, timedelta, timezone 


import conf


def lambda_handler(event, context):
    # TODO implement
    #print("Received event: " + json.dumps(event, indent=2))
    print("value3 = " + event['key3'])    

    #print("window length is {}".format(conf.WINDOWLEN))
    
    #start time, end time, segment start , segment end etc
    dict_time = define_window_timestamp(180, 50)
    for key, val in dict_time.items():
        print(key)
        print(val)
    
   
    #response =get_window_data(10, dict_time)
    #return response
    
    
    
    #generate records df for last 5 mins
    #resp_df = form_dataframe(response)
    
    #filter out devices that signals are stable in the last 5 mins
    #resp_df_unstable = filter_stable(resp_df)
    
    #For devices singla unstable, split N(e.g 90) seconds front and end segment if possible
    #start, mid, end = segment_signal(N)
    
    #Process 0 stable, one stable and two stable segment conditions
    #two stable condition will lead to the classfication (prediction), if it is move in or move out
    #--The, 
    
    
    
    #test2. successful
#     return {
#         'num_items': table.item_count,
#         'primary_key_name': table.key_schema[0],
#         'status': table.table_status,
#         'bytes_size': table.table_size_bytes,
#         'global_secondary_indices': table.global_secondary_indexes
#     }

    # TODO implement
    #return {
    #    'statusCode': 200,
    #    'body': json.dumps('Hello from Lambda!')
    #}


test_json = {
  "key2": "63982",
  "key3": "999"
}

#response = lambda_handler(test_json, None)

# %%
#from IPython.core.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

from IPython.display import display, HTML

display(HTML(data="""
<style>
    div#notebook-container    { width: 95%; }
    div#menubar-container     { width: 65%; }
    div#maintoolbar-container { width: 99%; }
</style>
"""))
# Out:
# <style>
#     div#notebook-container    { width: 95%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
#import datetime.timezone as timezone
#datetime.now(timezone.utc)

def define_window_timestamp2(WINDOWLEN, SEGLEN):    
    time_dict = dict()
    #time window FROM to TO
    time_dict['utcNow'] = datetime.now(timezone.utc)
    time_dict['utcWindowStart'] = time_dict['utcNow'] - timedelta(seconds=WINDOWLEN)
    #2019-11-15 02:51:07.966474 to
    #2019-11-06T22:49:27
    
    time_dict['utcNowStr'] = time_dict['utcNow'].strftime("%Y-%m-%dT%H:%M:%S").split('.')[0]
    time_dict['utcWindowStartStr'] = time_dict['utcWindowStart'].strftime("%Y-%m-%dT%H:%M:%S").split('.')[0]
    #datetime_object2 = datetime.strptime(x.split('.')[0], '%Y-%m-%dT%H:%M:%S')
    

    
    
    #also add segment 3 start and segment 1 end timestamp
    time_dict['utcSeg3Start'] = time_dict['utcNow'] - timedelta(seconds=SEGLEN)
    time_dict['utcSeg1End'] = time_dict['utcWindowStart'] + timedelta(seconds=SEGLEN)

    time_dict['utcSeg3StartStr'] = time_dict['utcSeg3Start'].strftime("%Y-%m-%dT%H:%M:%S").split('.')[0]
    time_dict['utcSeg1EndStr'] = time_dict['utcSeg1End'].strftime("%Y-%m-%dT%H:%M:%S").split('.')[0]    
    
    utcToday = time_dict['utcNow'].strftime("%Y%m%d").split('.')[0]
    utcYesterday = (time_dict['utcNow']-timedelta(days=1)).strftime("%Y%m%d").split('.')[0]
    time_dict['utcTodayYesterdayStr'] =  [utcToday, utcYesterday]
    return time_dict

dict_time = define_window_timestamp2(300, 90)

for key, val in dict_time.items():
    print(key)
    print(val)
# Out:
# utcNow
# 2019-11-17 22:28:02.156566+00:00
# utcWindowStart
# 2019-11-17 22:23:02.156566+00:00
# utcNowStr
# 2019-11-17T22:28:02
# utcWindowStartStr
# 2019-11-17T22:23:02
# utcSeg3Start
# 2019-11-17 22:26:32.156566+00:00
# utcSeg1End
# 2019-11-17 22:24:32.156566+00:00
# utcSeg3StartStr
# 2019-11-17T22:26:32
# utcSeg1EndStr
# 2019-11-17T22:24:32
# utcTodayYesterdayStr
# ['20191117', '20191116']

# %%
def get_window_data(WINDOWLEN, dict_time):
    # The boto3 dynamoDB resource, connectoin
    dynamodb_resource = resource('dynamodb',region_name='us-west-2')
    table = dynamodb_resource.Table('20191117')   

   
    #test1  
    #fe = Key('date_id').eq('2019-11-17') & \
    #        Key('time').between(dict_time['utcWindowStartStr'],dict_time['utcNowStr']);   

    #test1  , not successful because parition key can NOT use between    
    #fe = Key('date_id').between(dict_time['utcTodayYesterdayStr'][1], dict_time['utcTodayYesterdayStr'][0]) & \
    #        Key('time').between(dict_time['utcWindowStartStr'],dict_time['utcNowStr']); 
    
    fe = Key('date_id').eq(dict_time['utcTodayYesterdayStr'][0]) & \
            Key('time_id').between(dict_time['utcWindowStartStr'],dict_time['utcNowStr']) 
    pe = "date_id, app_id, dev_id, time_id, x, y, z"
    #response = table.query(KeyConditionExpression=fe)
    response = table.query(ProjectionExpression=pe, KeyConditionExpression=fe)
    
    while 'LastEvaluatedKey' in response:
        response = table.query(
            ProjectionExpression=pe,
            KeyConditionExpression=fe,
            ExclusiveStartKey=response['LastEvaluatedKey']
            )
        #for i in response['Items']:
        #    print("***in the loop***")
        #    print(i['dev_id'], ":", i['time'], i['payload_fields'])
    
    
#    #to be added in week four (The week start on 25th Nov)
#    #the window is the beginning to today; it will need end of yesterday's data(based on utc) to support
#    #get the the last window from yesteray and append records to ...
#    if :
#        fe = Key('date_id').eq(dict_time['utcTodayYesterdayStr'][0]) & \
#                Key('time').between(dict_time['utcWindowStartStr'],dict_time['utcNowStr']);  
#    
#        #append the 

    #print(response)
    return response


response = get_window_data(300, dict_time)


for key, val in response.items():
    print("key is:{}".format(key))
    print("val is:{}".format(val))


for i in response['Items']:
    print("***in the loop***")
#    print(i['dev_id'], ":", i['time_id'], i['payload_fields'])
    print(i['dev_id'], ":", i['time_id'])
print(response)
# Out:
# key is:Items
# val is:[{'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '564', 'y': '847', 'z': '-705', 'time_id': '2019-11-17T22:23:09.62038014Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '563', 'y': '847', 'z': '-707', 'time_id': '2019-11-17T22:23:23.041630288Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '848', 'z': '-705', 'time_id': '2019-11-17T22:23:36.97172007Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '847', 'z': '-704', 'time_id': '2019-11-17T22:23:51.859511832Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '846', 'z': '-706', 'time_id': '2019-11-17T22:24:06.893639904Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '846', 'z': '-707', 'time_id': '2019-11-17T22:24:21.20450768Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '849', 'z': '-707', 'time_id': '2019-11-17T22:24:35.608803161Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '561', 'y': '845', 'z': '-706', 'time_id': '2019-11-17T22:24:50.187363573Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '561', 'y': '851', 'z': '-709', 'time_id': '2019-11-17T22:25:05.392655141Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '847', 'z': '-707', 'time_id': '2019-11-17T22:25:19.576162792Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '845', 'z': '
z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '564', 'y': '845', 'z': '-706', 'time_id': '2019-11-17T22:26:31.051683885Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '563', 'y': '847', 'z': '-708', 'time_id': '2019-11-17T22:26:45.388034151Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '845', 'z': '-707', 'time_id': '2019-11-17T22:26:59.55904537Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '564', 'y': '848', 'z': '-707', 'time_id': '2019-11-17T22:27:12.895330874Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '562', 'y': '846', 'z': '-705', 'time_id': '2019-11-17T22:27:28.009374202Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '561', 'y': '848', 'z': '-708', 'time_id': '2019-11-17T22:27:42.912936934Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '561', 'y': '845', 'z': '-707', 'time_id': '2019-11-17T22:27:57.011959505Z'}], 'Count': 21, 'ScannedCount': 21, 'ResponseMetadata': {'RequestId': 'FFB044U3U7N9S3ADHEMILR6J43VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Sun, 17 Nov 2019 22:29:03 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '3900', 'connection': 'keep-alive', 'x-amzn-requestid': 'FFB044U3U7N9S3ADHEMILR6J43VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '4269237481'}, 'RetryAttempts': 0}}

# %%
def form_dataframe(response):
    #function content for form_dataframe(response), response.items() is a multilayer dictionary
    #keys include items, count, scanned count, lastevaluatedkey etc...(Items contains data information)

    #generate dataframe from dictionary
    response_json_str = response['Items']    
    df = pd.io.json.json_normalize(response_json_str)
    df = df.astype({'x': 'int32', 'y': 'int32', 'z': 'int32'})
    
    #date_time_obj = datetime.datetime.strptime(date_time_str, '%Y-%m-%d %H:%M:%S.%f')
    df['time_id_obj'] = pd.to_datetime(df['time_id'], utc=True)
    
    display(df)
    return df

    #get x, y and z coordinate
#     list_xyz = [ i[1:].split('A') for i in df['payload_fields.payload']]
#     df_xyz = pd.DataFrame.from_records(list_xyz)
#     df_xyz.columns=['x','y','z','battery']
#     df_xyz = df_xyz.astype({'x': 'int32', 'y': 'int32', 'z': 'int32'})
#     df_xyz = pd.concat([df_xyz,df[['time','app_id','dev_id']]], axis=1)
#    return df_xyz


df_xyz = form_dataframe(response)
for key, val in response.items():
    print("key is:{}".format(key))
    print("val is:{}".format(val))
#print(df_xyz)
# Out:
#            app_id   date_id    dev_id    x    y    z  \
# 0   ttnctl_test32  20191117  node32_3  564  847 -705
# 1   ttnctl_test32  20191117  node32_3  563  847 -707
# 2   ttnctl_test32  20191117  node32_3  562  848 -705
# 3   ttnctl_test32  20191117  node32_3  562  847 -704
# 4   ttnctl_test32  20191117  node32_3  562  846 -706
# 5   ttnctl_test32  20191117  node32_3  562  846 -707
# 6   ttnctl_test32  20191117  node32_3  562  849 -707
# 7   ttnctl_test32  20191117  node32_3  561  845 -706
# 8   ttnctl_test32  20191117  node32_3  561  851 -709
# 9   ttnctl_test32  20191117  node32_3  562  847 -707
# 10  ttnctl_test32  20191117  node32_3  562  845 -708
# 11  ttnctl_test32  20191117  node32_3  563  849 -708
# 12  ttnctl_test32  20191117  node32_3  566  845 -705
# 13  ttnctl_test32  20191117  node32_3  561  846 -707
# 14  ttnctl_test32  20191117  node32_3  564  845 -706
# 15  ttnctl_test32  20191117  node32_3  563  847 -708
# 16  ttnctl_test32  20191117  node32_3  562  845 -707
# 17  ttnctl_test32  20191117  node32_3  564  848 -707
# 18  ttnctl_test32  20191117  node32_3  562  846 -705
# 19  ttnctl_test32  20191117  node32_3  561  848 -708
# 20  ttnctl_test32  20191117  node32_3  561  845 -707
#
#                            time_id                         time_id_obj
# 0    2019-11-17T22:23:09.62038014Z 2019-11-17 22:23:09.620380140+00:00
# 1   2019-11-17T22:23:23.041630288Z 2019-11-17 22:23:23.041630288+00:00
z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '561', 'y': '848', 'z': '-708', 'time_id': '2019-11-17T22:27:42.912936934Z'}, {'app_id': 'ttnctl_test32', 'date_id': '20191117', 'dev_id': 'node32_3', 'x': '561', 'y': '845', 'z': '-707', 'time_id': '2019-11-17T22:27:57.011959505Z'}]
# key is:Count
# val is:21
# key is:ScannedCount
# val is:21
# key is:ResponseMetadata
# val is:{'RequestId': 'FFB044U3U7N9S3ADHEMILR6J43VV4KQNSO5AEMVJF66Q9ASUAAJG', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'Server', 'date': 'Sun, 17 Nov 2019 22:29:03 GMT', 'content-type': 'application/x-amz-json-1.0', 'content-length': '3900', 'connection': 'keep-alive', 'x-amzn-requestid': 'FFB044U3U7N9S3ADHEMILR6J43VV4KQNSO5AEMVJF66Q9ASUAAJG', 'x-amz-crc32': '4269237481'}, 'RetryAttempts': 0}

# %%
#function content for filter_stable(resp_df):
#for those devices with at least N data point
#check the standard deviation value for each device (for the last N minutes)
    
def filter_stable(df_xyz, groupCountWin, XStdWin, YStdWin, ZStdWin):
    
    display("***input:")
    display(df_xyz)
    df_xyz_std = df_xyz.groupby(['app_id','dev_id'])[['x','y','z']] \
                .std() \
                .reset_index()
    # How many entries are there for each device?
    df_xyz_count = df_xyz.groupby(['app_id','dev_id'])['x'] \
                .count() \
                .reset_index() 
    df_xyz_count.rename(columns={'x':'ct'}, inplace=True)
    df_xyz_agg = pd.merge(df_xyz_std, df_xyz_count, on=['app_id','dev_id']).reset_index()
 
    #print(df_xyz_count)
    #print(df_xyz_std)

    display(df_xyz_agg)
    df_xyz_agg_significant = df_xyz_agg[  (df_xyz_agg.ct >= groupCountWin)  \
                                           & (df_xyz_agg.x >= XStdWin)  \
                                           & (df_xyz_agg.y >= YStdWin) \
                                           & (df_xyz_agg.z >= ZStdWin) ]

    print("***significant update found for following devices:")
    display(df_xyz_agg_significant)  
    
    df_xyz_significant = pd.merge(df_xyz_agg_significant[['app_id','dev_id','ct']], df_xyz, on=['app_id','dev_id']).reset_index()

    print("***significant records moving to the next phase:")
    display(df_xyz_significant)  

    return df_xyz_significant
    
#df_xyz_significant = filter_stable(df_xyz, 6, 1.5, 1.5, 1.5)    
df_xyz_significant = filter_stable(df_xyz, 6, 1.2, 1.2, 1.2)
# Out:
# '***input:'
#            app_id   date_id    dev_id    x    y    z  \
# 0   ttnctl_test32  20191117  node32_3  564  847 -705
# 1   ttnctl_test32  20191117  node32_3  563  847 -707
# 2   ttnctl_test32  20191117  node32_3  562  848 -705
# 3   ttnctl_test32  20191117  node32_3  562  847 -704
# 4   ttnctl_test32  20191117  node32_3  562  846 -706
# 5   ttnctl_test32  20191117  node32_3  562  846 -707
# 6   ttnctl_test32  20191117  node32_3  562  849 -707
# 7   ttnctl_test32  20191117  node32_3  561  845 -706
# 8   ttnctl_test32  20191117  node32_3  561  851 -709
# 9   ttnctl_test32  20191117  node32_3  562  847 -707
# 10  ttnctl_test32  20191117  node32_3  562  845 -708
# 11  ttnctl_test32  20191117  node32_3  563  849 -708
# 12  ttnctl_test32  20191117  node32_3  566  845 -705
# 13  ttnctl_test32  20191117  node32_3  561  846 -707
# 14  ttnctl_test32  20191117  node32_3  564  845 -706
# 15  ttnctl_test32  20191117  node32_3  563  847 -708
# 16  ttnctl_test32  20191117  node32_3  562  845 -707
# 17  ttnctl_test32  20191117  node32_3  564  848 -707
# 18  ttnctl_test32  20191117  node32_3  562  846 -705
# 11     11  ttnctl_test32  node32_3  21  20191117  563  849 -708
# 12     12  ttnctl_test32  node32_3  21  20191117  566  845 -705
# 13     13  ttnctl_test32  node32_3  21  20191117  561  846 -707
# 14     14  ttnctl_test32  node32_3  21  20191117  564  845 -706
# 15     15  ttnctl_test32  node32_3  21  20191117  563  847 -708
# 16     16  ttnctl_test32  node32_3  21  20191117  562  845 -707
# 17     17  ttnctl_test32  node32_3  21  20191117  564  848 -707
# 18     18  ttnctl_test32  node32_3  21  20191117  562  846 -705
# 19     19  ttnctl_test32  node32_3  21  20191117  561  848 -708
# 20     20  ttnctl_test32  node32_3  21  20191117  561  845 -707
#
#                            time_id                         time_id_obj
# 0    2019-11-17T22:23:09.62038014Z 2019-11-17 22:23:09.620380140+00:00
# 1   2019-11-17T22:23:23.041630288Z 2019-11-17 22:23:23.041630288+00:00
# 2    2019-11-17T22:23:36.97172007Z 2019-11-17 22:23:36.971720070+00:00
# 3   2019-11-17T22:23:51.859511832Z 2019-11-17 22:23:51.859511832+00:00
# 4   2019-11-17T22:24:06.893639904Z 2019-11-17 22:24:06.893639904+00:00
# 5    2019-11-17T22:24:21.20450768Z 2019-11-17 22:24:21.204507680+00:00
# 6   2019-11-17T22:24:35.608803161Z 2019-11-17 22:24:35.608803161+00:00
# 7   2019-11-17T22:24:50.187363573Z 2019-11-17 22:24:50.187363573+00:00
# 8   2019-11-17T22:25:05.392655141Z 2019-11-17 22:25:05.392655141+00:00
# 9   2019-11-17T22:25:19.576162792Z 2019-11-17 22:25:19.576162792+00:00
# 10  2019-11-17T22:25:33.264312688Z 2019-11-17 22:25:33.264312688+00:00
# 11  2019-11-17T22:25:46.885958747Z 2019-11-17 22:25:46.885958747+00:00
# 12  2019-11-17T22:26:01.665365851Z 2019-11-17 22:26:01.665365851+00:00
# 13  2019-11-17T22:26:16.386252025Z 2019-11-17 22:26:16.386252025+00:00
# 14  2019-11-17T22:26:31.051683885Z 2019-11-17 22:26:31.051683885+00:00
# 15  2019-11-17T22:26:45.388034151Z 2019-11-17 22:26:45.388034151+00:00
# 16   2019-11-17T22:26:59.55904537Z 2019-11-17 22:26:59.559045370+00:00
# 17  2019-11-17T22:27:12.895330874Z 2019-11-17 22:27:12.895330874+00:00
# 18  2019-11-17T22:27:28.009374202Z 2019-11-17 22:27:28.009374202+00:00
# 19  2019-11-17T22:27:42.912936934Z 2019-11-17 22:27:42.912936934+00:00
# 20  2019-11-17T22:27:57.011959505Z 2019-11-17 22:27:57.011959505+00:00

# %%
#for each device, function content to fetch the front and end window(N seconds):
#utcWindowStart

def segment_signal(df_seg, WINDOWLEN, SEGLEN, dict_time):
    for key, val in dict_time.items():
        print(key)
        print(val)
        
#    df_seg['time_id_time'] = pd.to_datetime(df_seg['time_id'])
#     #the 3rd segment start
#     seg3Start = dict_time['utcNow'] - timedelta(seconds=SEGLEN)
#     seg1Start = dict_time['utcNow'] - timedelta(seconds=WINDOWLEN)
#     seg1End = seg1Start + timedelta(seconds=SEGLEN)
    
#     #segment annotation  
    df_seg.loc[(df_seg['time_id_obj'] >= dict_time['utcWindowStart']) & (df_seg['time_id_obj'] <= dict_time['utcSeg1End']), 'segment'] = 1
    df_seg.loc[(df_seg['time_id_obj'] >= dict_time['utcSeg3Start']) & (df_seg['time_id_obj'] <= dict_time['utcNow']), 'segment'] = 3    
    df_seg.loc[(df_seg['time_id_obj'] > dict_time['utcSeg1End']) & (df_seg['time_id_obj'] < dict_time['utcSeg3Start']), 'segment'] = 2   
    
    return df_seg

#segment_signal(df_xyz_significant, 76, 20, '2019-11-06T22:50:42.949110202Z')
df_seg = segment_signal(df_xyz_significant, 76, 20, dict_time)
display(df_seg)
#display(df_xyz_significant)
# Out:
# utcNow
# 2019-11-17 22:28:02.156566+00:00
# utcWindowStart
# 2019-11-17 22:23:02.156566+00:00
# utcNowStr
# 2019-11-17T22:28:02
# utcWindowStartStr
# 2019-11-17T22:23:02
# utcSeg3Start
# 2019-11-17 22:26:32.156566+00:00
# utcSeg1End
# 2019-11-17 22:24:32.156566+00:00
# utcSeg3StartStr
# 2019-11-17T22:26:32
# utcSeg1EndStr
# 2019-11-17T22:24:32
# utcTodayYesterdayStr
# ['20191117', '20191116']
#     index         app_id    dev_id  ct   date_id    x    y    z  \
# 0       0  ttnctl_test32  node32_3  21  20191117  564  847 -705
# 1       1  ttnctl_test32  node32_3  21  20191117  563  847 -707
# 2       2  ttnctl_test32  node32_3  21  20191117  562  848 -705
# 3       3  ttnctl_test32  node32_3  21  20191117  562  847 -704
# 4       4  ttnctl_test32  node32_3  21  20191117  562  846 -706
# 5       5  ttnctl_test32  node32_3  21  20191117  562  846 -707
# 6       6  ttnctl_test32  node32_3  21  20191117  562  849 -707
# 7       7  ttnctl_test32  node32_3  21  20191117  561  845 -706
# 8       8  ttnctl_test32  node32_3  21  20191117  561  851 -709
# 9       9  ttnctl_test32  node32_3  21  20191117  562  847 -707
# 10     10  ttnctl_test32  node32_3  21  20191117  562  845 -708
# 11     11  ttnctl_test32  node32_3  21  20191117  563  849 -708
# 12     12  ttnctl_test32  node32_3  21  20191117  566  845 -705
# 13     13  ttnctl_test32  node32_3  21  20191117  561  846 -707
# 14     14  ttnctl_test32  node32_3  21  20191117  564  845 -706
# 15     15  ttnctl_test32  node32_3  21  20191117  563  847 -708
# 16     16  ttnctl_test32  node32_3  21  20191117  562  845 -707
# 17     17  ttnctl_test32  node32_3  21  20191117  564  848 -707
# 18     18  ttnctl_test32  node32_3  21  20191117  562  846 -705
# 19     19  ttnctl_test32  node32_3  21  20191117  561  848 -708
# 20     20  ttnctl_test32  node32_3  21  20191117  561  845 -707
#
#                            time_id                         time_id_obj  \
# 0    2019-11-17T22:23:09.62038014Z 2019-11-17 22:23:09.620380140+00:00
# 1   2019-11-17T22:23:23.041630288Z 2019-11-17 22:23:23.041630288+00:00
# 2    2019-11-17T22:23:36.97172007Z 2019-11-17 22:23:36.971720070+00:00
# 3   2019-11-17T22:23:51.859511832Z 2019-11-17 22:23:51.859511832+00:00
# 4   2019-11-17T22:24:06.893639904Z 2019-11-17 22:24:06.893639904+00:00
# 5    2019-11-17T22:24:21.20450768Z 2019-11-17 22:24:21.204507680+00:00
# 6   2019-11-17T22:24:35.608803161Z 2019-11-17 22:24:35.608803161+00:00
# 7   2019-11-17T22:24:50.187363573Z 2019-11-17 22:24:50.187363573+00:00
# 8   2019-11-17T22:25:05.392655141Z 2019-11-17 22:25:05.392655141+00:00
# 9   2019-11-17T22:25:19.576162792Z 2019-11-17 22:25:19.576162792+00:00
# 10  2019-11-17T22:25:33.264312688Z 2019-11-17 22:25:33.264312688+00:00
# 11  2019-11-17T22:25:46.885958747Z 2019-11-17 22:25:46.885958747+00:00
# 12  2019-11-17T22:26:01.665365851Z 2019-11-17 22:26:01.665365851+00:00
# 13  2019-11-17T22:26:16.386252025Z 2019-11-17 22:26:16.386252025+00:00
# 14  2019-11-17T22:26:31.051683885Z 2019-11-17 22:26:31.051683885+00:00
# 15  2019-11-17T22:26:45.388034151Z 2019-11-17 22:26:45.388034151+00:00
# 16   2019-11-17T22:26:59.55904537Z 2019-11-17 22:26:59.559045370+00:00
# 17  2019-11-17T22:27:12.895330874Z 2019-11-17 22:27:12.895330874+00:00
# 18  2019-11-17T22:27:28.009374202Z 2019-11-17 22:27:28.009374202+00:00
# 19  2019-11-17T22:27:42.912936934Z 2019-11-17 22:27:42.912936934+00:00
# 20  2019-11-17T22:27:57.011959505Z 2019-11-17 22:27:57.011959505+00:00
#
#     segment
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# 5       1.0
# 6       2.0
# 7       2.0
# 8       2.0
# 9       2.0
# 10      2.0
# 11      2.0
# 12      2.0
# 13      2.0
# 14      2.0
# 15      3.0
# 16      3.0
# 17      3.0
# 18      3.0
# 19      3.0
# 20      3.0

# %%
now = datetime.now()
N_seconds_ago = now - timedelta(seconds=3)  

#print(now)
#print(N_seconds_ago)

if now - timedelta(seconds=2) > N_seconds_ago :
    print("comparison works")


if now - timedelta(seconds=10) < N_seconds_ago :
    print("comparison works")

  

    
x= '2019-11-06T22:50:42.949110202Z'
#x= '2019-11-06T22:50:42.949110'
#print(x.strptime("%Y-%m-%dT%H:%M:%S%Z"))


datetime_str = '09/19/18 13:55:26'

datetime_object = datetime.strptime(datetime_str, '%m/%d/%y %H:%M:%S')

print(type(datetime_object))
print(datetime_object)  # printed in default format


#please note the last three digit and z cannot be handled by strptime
#please note the Z stands for the Zero timezone, as it is offset by 0 from the Coordinated Universal Time (UTC).
datetime_object2 = datetime.strptime(x.split('.')[0], '%Y-%m-%dT%H:%M:%S')
print(datetime_object2)

# %%
WINDOWLEN=300

utcNow = datetime.utcnow()
utcWindowStart = utcNow - timedelta(seconds=WINDOWLEN)

print(utcNow)
print(utcWindowStart)

# %%
now = datetime.now() # current date and time
year = now.strftime("%Y")
print("year:", year)
month = now.strftime("%m")
print("month:", month)
day = now.strftime("%d")
print("day:", day)


time = now.strftime("%H:%M:%S")
print("time:", time)

date_time = now.strftime("%m/%d/%Y, %H:%M:%S")
print("date and time:",date_time)
